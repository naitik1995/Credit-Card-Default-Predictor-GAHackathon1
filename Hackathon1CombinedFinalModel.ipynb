# %%
import numpy as np 
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt  
import seaborn as sns
from scipy import stats
#For some Statistics
from scipy.stats import norm, skew
from sklearn.preprocessing import Imputer,StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score,recall_score,f1_score,roc_auc_score,confusion_matrix,precision_score,classification_report,make_scorer
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from xgboost import XGBClassifier
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Fetching data and understanding dataset

# %%
data_main = pd.read_excel("./defaultofcreditcardclients.xls", header=1,index_col=0)

# %%
data_main.describe()
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    167484.322667      1.603733      1.853133      1.551867     35.485500
# std     129747.661567      0.489129      0.790349      0.521970      9.217904
# min      10000.000000      1.000000      0.000000      0.000000     21.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000
#
#               PAY_0         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.016700     -0.133767     -0.166200     -0.220667     -0.266200
# ...

# %%
data_main.head()
# Out:
#     LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID
# 1       20000    2          2         1   24      2      2     -1     -1
# 2      120000    2          2         2   26     -1      2      0      0
# 3       90000    2          2         2   34      0      0      0      0
# 4       50000    2          2         1   37      0      0      0      0
# 5       50000    1          2         1   57     -1      0     -1      0
#
#     PAY_5             ...              BILL_AMT4  BILL_AMT5  BILL_AMT6  \
# ID                    ...
# 1      -2             ...                      0          0          0
# 2       0             ...                   3272       3455       3261
# 3       0             ...                  14331      14948      15549
# 4       0             ...                  28314      28959      29547
# 5       0             ...                  20940      19146      19131
#
#     PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# ...

# %%
data_main.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30000 entries, 1 to 30000
# Data columns (total 24 columns):
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# BILL_AMT5                     30000 non-null int64
# ...

# %%
data_main.shape
# Out:
# (30000, 24)

# %% [markdown]
# # checking null values

# %%
data_main.isnull().sum()
# Out:
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %% [markdown]
# # checking count of defaults in given datasets

# %%
sns.countplot(data_main['default payment next month'])
total=data_main['default payment next month'].count()
zero=data_main[data_main['default payment next month']==0].shape[0]
one=data_main[data_main['default payment next month']==1].shape[0]
percent_zero=zero/total
percent_one=one/total

##Observations:
##For the entire data set, approximately 22.1% of the individuals defaulted.
##For the entire data set, approximately 77.88% of the individuals are not defaulted.

# %% [markdown]
# # Identifying unique values, categoric features, numeric features.

# %%
unique_values = {}
cat_col=[]
num_col=[]
for column in data_main.columns:
    unique_values[column] = len(np.unique(data_main[column]))
    if(len(np.unique(data_main[column]))<=9):
        cat_col.append(column)
        data_main[column]=data_main[column].astype(np.object)
    else:
        num_col.append(column)
data_main['default payment next month']=data_main['default payment next month'].astype(np.int64)        
print("Unique Values :: "+str(unique_values)+'\n')
print("Categoric features :: "+str(cat_col)+'\n')
print("Numeric features :: "+str(num_col))
# Out:
# Unique Values :: {'LIMIT_BAL': 81, 'SEX': 2, 'EDUCATION': 7, 'MARRIAGE': 4, 'AGE': 56, 'PAY_0': 11, 'PAY_2': 11, 'PAY_3': 11, 'PAY_4': 11, 'PAY_5': 10, 'PAY_6': 10, 'BILL_AMT1': 22723, 'BILL_AMT2': 22346, 'BILL_AMT3': 22026, 'BILL_AMT4': 21548, 'BILL_AMT5': 21010, 'BILL_AMT6': 20604, 'PAY_AMT1': 7943, 'PAY_AMT2': 7899, 'PAY_AMT3': 7518, 'PAY_AMT4': 6937, 'PAY_AMT5': 6897, 'PAY_AMT6': 6939, 'default payment next month': 2}
#
# Categoric features :: ['SEX', 'EDUCATION', 'MARRIAGE', 'default payment next month']
#
# Numeric features :: ['LIMIT_BAL', 'AGE', 'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']

# %% [markdown]
# # Checking correlation b/w Numeric vs Numeric

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data_main.corr(), cmap='viridis',annot=True)

# %% [markdown]
# # Checking count with crosstab Categorical vs categorical

# %%
for i in cat_col:
    crosstab = pd.crosstab(index=data_main[i], columns=data_main['default payment next month'])
    crosstab.plot(kind="bar", figsize=(5,5), stacked=False, colormap='Paired')
    print(crosstab)
# Out:
# default payment next month      0     1
# SEX
# 1                            9015  2873
# 2                           14349  3763
# default payment next month      0     1
# EDUCATION
# 0                              14     0
# 1                            8549  2036
# 2                           10700  3330
# 3                            3680  1237
# 4                             116     7
# 5                             262    18
# 6                              43     8
# default payment next month      0     1
# MARRIAGE
# 0                              49     5
# 1                           10453  3206
# 2                           12623  3341
# 3                             239    84
# default payment next month      0     1
# default payment next month
# 0                           23364     0
# 1                               0  6636

# %% [markdown]
# # Cleaning Categorical data and applying One hot encoding

# %%
def replaceEducationjunk(df):
    df['EDUCATION'].replace(0, 4,inplace=True)
    df['EDUCATION'].replace(5, 4,inplace=True)
    df['EDUCATION'].replace(6, 4,inplace=True)
    return df
replaceEducationjunk(data_main)
crosstab = pd.crosstab(index=data_main['EDUCATION'], columns=data_main['default payment next month'])
print(crosstab)

def replaceMARRIAGEjunk(df):
    df['MARRIAGE'].replace(0, 3,inplace=True)
    return df
replaceMARRIAGEjunk(data_main)
crosstab = pd.crosstab(index=data_main['MARRIAGE'], columns=data_main['default payment next month'])
print(crosstab)

cat_col2=['SEX','MARRIAGE','EDUCATION']
data_main=pd.get_dummies(data_main,columns=cat_col2,drop_first=True)
data_main.info()
# Out:
# default payment next month      0     1
# EDUCATION
# 1                            8549  2036
# 2                           10700  3330
# 3                            3680  1237
# 4                             435    33
# default payment next month      0     1
# MARRIAGE
# 1                           10453  3206
# 2                           12623  3341
# 3                             288    89
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30000 entries, 1 to 30000
# Data columns (total 27 columns):
# LIMIT_BAL                     30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# ...

# %% [markdown]
# # Plot to see distribution for numeric data

# %%
num_cols = num_col
for i in range(0,len(num_cols),2):
    if len(num_cols) > i+1:
        plt.figure(figsize=(10,4))
        plt.subplot(121)
        sns.distplot(data_main[num_cols[i]], hist=True, kde=True)
        plt.subplot(122)            
        sns.distplot(data_main[num_cols[i+1]], hist=True, kde=True)
        plt.tight_layout()
        plt.show()

    else:
        sns.distplot(data_main[num_cols[i]], hist=True, kde=True)

# %%
# Log-transform the skewed features
skewed = ['LIMIT_BAL', 'AGE','BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']
skewed_m=dict()
for s in skewed:
    skewed_m[s] = skew(data_main[s])
print(skewed_m)



print(data_main.isnull().sum())

#features_log_transformed = pd.DataFrame(data = data_main)
data_main['LIMIT_BAL'] = data_main['LIMIT_BAL'].apply(lambda x: np.sqrt(x))
data_main['AGE'] = data_main['AGE'].apply(lambda x: np.sqrt(x))



scaler = StandardScaler()
data_main[skewed] = scaler.fit_transform(data_main[skewed])


print(data_main.isnull().sum())

for s in skewed:
    skewed_m[s] = skew(data_main[s])
print(skewed_m)
# Out:
# {'LIMIT_BAL': 0.9928173164820109, 'AGE': 0.7322092559811012, 'BILL_AMT1': 2.6637278271222136, 'BILL_AMT2': 2.7050855904869455, 'BILL_AMT3': 3.087675652554038, 'BILL_AMT4': 2.821824190578528, 'BILL_AMT5': 2.876236045711996, 'BILL_AMT6': 2.846502241454702, 'PAY_AMT1': 14.667630904439925, 'PAY_AMT2': 30.452294738147945, 'PAY_AMT3': 17.215774591401207, 'PAY_AMT4': 12.904339565339363, 'PAY_AMT5': 11.126860673593654, 'PAY_AMT6': 10.640195281288497}
# LIMIT_BAL                     0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# ...

# %%
num_cols = num_col
for i in range(0,len(num_cols),2):
    if len(num_cols) > i+1:
        plt.figure(figsize=(10,4))
        plt.subplot(121)
        sns.distplot(data_main[num_cols[i]], hist=True, kde=True)
        plt.subplot(122)            
        sns.distplot(data_main[num_cols[i+1]], hist=True, kde=True)
        plt.tight_layout()
        plt.show()

    else:
        sns.distplot(data_main[num_cols[i]], hist=True, kde=True)

# %% [markdown]
# # Preparing data

# %%
col=list(data_main.columns)
col.remove('default payment next month')
print(col)

X=data_main[col]
y=data_main['default payment next month']
#split dataset into train and test
X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.30,random_state=9)
# Out:
# ['LIMIT_BAL', 'AGE', 'PAY_0', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'SEX_2', 'MARRIAGE_2', 'MARRIAGE_3', 'EDUCATION_2', 'EDUCATION_3', 'EDUCATION_4']

# %% [markdown]
# # Build model with Logistic Regression with parameter tuning

# %%
#logistic regression
logistic_regressor = LogisticRegression(n_jobs=-1)
pipeline = Pipeline(steps=[('add_poly_features', PolynomialFeatures()),('logistic_regression', logistic_regressor)])
params = {'add_poly_features__degree':[2,3,4,5],'logistic_regression__penalty':['l1','l2']}

grid_search = GridSearchCV(estimator=pipeline, param_grid=params)
grid_search.fit(X_train,y_train)
#pipelineM=logistic_regressor.fit(X_train,y_train)
print(grid_search.best_params_)
# Out:
# C:\Users\Hardika\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Users\Hardika\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Users\Hardika\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Users\Hardika\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# ...

# %%
grid_search.best_params_
# Out:
# {'add_poly_features__degree': 2, 'logistic_regression__penalty': 'l1'}

# %%
#predict
y_pred = grid_search.predict(X_test)
y_train_pred = grid_search.predict(X_train)
#score for Logistic regression train 70%
print("Accuracy Score"+str(accuracy_score(y_train, y_train_pred)))
print("ROC AUC Score"+str(roc_auc_score(y_train, y_train_pred)))
print(classification_report(y_train, y_train_pred))
print(confusion_matrix(y_train, y_train_pred))
print("-------------------------------------------------------------------------------------------")
#score for Logistic regression test 30%
print("Accuracy Score"+str(accuracy_score(y_test, y_pred)))
print("ROC AUC Score"+str(roc_auc_score(y_test, y_pred)))
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy Score0.8208571428571428
# ROC AUC Score0.6476685536477423
#              precision    recall  f1-score   support
#
#           0       0.84      0.96      0.89     16341
#           1       0.70      0.34      0.45      4659
#
# avg / total       0.81      0.82      0.80     21000
#
# [[15671   670]
#  [ 3092  1567]]
# -------------------------------------------------------------------------------------------
# Accuracy Score0.8136666666666666
# ROC AUC Score0.635838088465884
#              precision    recall  f1-score   support
#
#           0       0.83      0.95      0.89      7023
#           1       0.66      0.32      0.43      1977
#
# avg / total       0.79      0.81      0.79      9000
#
# [[6693  330]
#  [1347  630]]

# %%
#Note: Tried feature selection on Logistic Regression also, but no improvement found.

# %% [markdown]
# # Model RandomForest and feature selection

# %%
#1. fitting train data with RF
#2. Applying feature selection
#3. refitting with selected feature

# %%
#IMP features
##RF fit
rf = RandomForestClassifier(random_state=9)
rf.fit(X_train,y_train)
## predict
y_pred = rf.predict(X_test)

##Checking performance metrics
asrf = accuracy_score(y_test, y_pred)
aucrf = roc_auc_score(y_test, y_pred)
print("Accuracy score of the model "+str(asrf))
print("roc_auc_score of the model1 "+str(aucrf))
print(classification_report(y_test, y_pred))


### Feature selection
model_select = SelectFromModel(rf,prefit=True)
imp_features = X.columns.values[model_select.get_support()]
X2 = model_select.transform(X)
print(imp_features)
print(X2.shape)

#split dataset into train and test
X2_train,X2_test,y2_train,y2_test= train_test_split(X2,y,test_size=0.30)

#model for tuning the min samples of leaf
rffs = RandomForestClassifier( random_state=9)
rffs.fit(X2_train,y2_train)

# predicting for min_samples 0f leaf as 2.
y2_pred = rffs.predict(X2_test)

##Checking performance metrics
asrffs = accuracy_score(y2_test, y2_pred)
aucrffs = roc_auc_score(y2_test, y2_pred)
print("Accuracy score of the model "+str(asrffs))
print("roc_auc_score of the model "+str(aucrffs))
print(classification_report(y2_test, y2_pred))




# Plot the feature importances of the forest
importances = rffs.feature_importances_
std = np.std([tree.feature_importances_ for tree in rffs.estimators_], axis=0)
indices = np.argsort(importances)[::-1]


# Print the feature ranking
print("Feature ranking:")

for f in range(X2.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))
    
    
plt.figure()
plt.title("Feature importances")
plt.bar(range(X2.shape[1]), importances[indices],
       color="r", yerr=std[indices], align="center")
plt.xticks(range(X2.shape[1]), indices)
plt.xlim([-1, X2.shape[1]])
plt.show()
# Out:
# Accuracy score of the model 0.802
# roc_auc_score of the model1 0.631815212837421
#              precision    recall  f1-score   support
#
#           0       0.83      0.94      0.88      7023
#           1       0.59      0.33      0.42      1977
#
# avg / total       0.78      0.80      0.78      9000
#
# ['LIMIT_BAL' 'AGE' 'PAY_0' 'BILL_AMT1' 'BILL_AMT2' 'BILL_AMT3' 'BILL_AMT4'
#  'BILL_AMT5' 'BILL_AMT6' 'PAY_AMT1' 'PAY_AMT2' 'PAY_AMT3' 'PAY_AMT4'
#  'PAY_AMT5' 'PAY_AMT6']
# (30000, 15)
# Accuracy score of the model 0.8021111111111111
# roc_auc_score of the model 0.6261201382982878
#              precision    recall  f1-score   support
#
#           0       0.83      0.94      0.88      6994
#           1       0.61      0.31      0.41      2006
#
# avg / total       0.78      0.80      0.78      9000
#
# Feature ranking:
# 1. feature 2 (0.133454)
# 2. feature 1 (0.073719)
# 3. feature 0 (0.070338)
# 4. feature 3 (0.068770)
# 5. feature 9 (0.068480)
# 6. feature 4 (0.064855)
# ...

# %%
#Note No improvement with Feature selection.

# %% [markdown]
# # RF with Parameter Tuining

# %%
imp_features
# Out:
# array(['LIMIT_BAL', 'AGE', 'PAY_0', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3',
#        'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2',
#        'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6'], dtype=object)

# %%
parameter = {'n_estimators': [2,4,6,8,10],
             'max_features': ['log2', 'sqrt', 'auto'],
             'criterion': ['entropy', 'gini'],
             'max_depth': [2,4,6],
             'min_samples_split': [2,4,6],
             'min_samples_leaf': [2,4,6],
             'bootstrap': [True,False]
            }

# %%
def gridfunc(classifier, parameter, X_train, y_train):
       
    clf = classifier
    np.random.seed(9)
    parameters = parameter
    acc_scorer = make_scorer(accuracy_score) #what kind of performance measure you want
   
   # Run the grid search
    grid_obj = GridSearchCV(clf, parameters, scoring=acc_scorer) #find the best parameter out of all by comparing the accuracy score of all
    grid_obj = grid_obj.fit(X_train, y_train) #input to the next function
   
    return grid_obj
#task find the results for the given params
classifier = RandomForestClassifier(random_state=9,n_jobs=-1)
grid = gridfunc(classifier, parameter, X_train, y_train)

# %%
bp = grid.best_params_
bp
# Out:
# {'bootstrap': False,
#  'criterion': 'gini',
#  'max_depth': 6,
#  'max_features': 'log2',
#  'min_samples_leaf': 4,
#  'min_samples_split': 2,
#  'n_estimators': 10}

# %%
clf = grid.best_estimator_
clf
# Out:
# RandomForestClassifier(bootstrap=False, class_weight=None, criterion='gini',
#             max_depth=6, max_features='log2', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=4, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=9, verbose=0, warm_start=False)

# %%
   
# Fit the best algorithm to the data. 
clf.fit(X_train, y_train)

# predicting for min_samples 0f leaf as 2.
y_pred = clf.predict(X_test)

# Checking performance metrics
accuracy_clf_1 = accuracy_score(y_test, y_pred)
auc_roc1 = roc_auc_score(y_test, y_pred)
print("Accuracy score of the model with min sample leaf 6 is: {}".format(accuracy_clf_1))
print("roc_auc_score of the model1 is: {}".format(auc_roc1))
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy score of the model with min sample leaf 6 is: 0.8168888888888889
# roc_auc_score of the model1 is: 0.644989571442801
#              precision    recall  f1-score   support
#
#           0       0.84      0.95      0.89      7023
#           1       0.66      0.34      0.45      1977
#
# avg / total       0.80      0.82      0.79      9000
#
# [[6683  340]
#  [1308  669]]

# %% [markdown]
# # XGBOOST with parameter tuning

# %%
param_grid1 = {"max_depth": [2, 3, 4, 5, 6, 7, 9, 11],
               "min_child_weight": [4, 6, 7, 8,12],
               "subsample": [0.6, .7, .8, .9, 1],
               "colsample_bytree": [0.6, .7, .8, .9, 1]
               }
xgb = XGBClassifier(seed=9)

def myXGBoost(X_train, X_test, y_train, y_test, model, param_grid, KFold=3,**kwargs):
    
    for i, j in kwargs.items():
        lst1=list()
        lst1.append(j)
        param_grid[i]=lst1
        
    acc_scorer = make_scorer(accuracy_score)
    grid_obj = GridSearchCV(model, param_grid, scoring=acc_scorer,cv=KFold)
    grid_obj = grid_obj.fit(X_train, y_train)
    y_pred=grid_obj.predict(X_test)
    accuracy=accuracy_score(y_test,y_pred)
    best_params=grid_obj.best_params_
    auc_roc1 = roc_auc_score(y_test, y_pred)
    return grid_obj,accuracy,auc_roc1, best_params

# %%
xgbobj1,as1,auc1,bestparam1_=myXGBoost(X_train, X_test, y_train, y_test, xgb, param_grid1, KFold=3)
print(as1)
print(bestparam1_)
print(auc1)
# Out:
# C:\Users\Hardika\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Hardika\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Hardika\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# ...

# %%
param_grid2 = {"gamma": [0, 0.05, 0.1,0.2, 0.3, 0.7, 0.9, 1],
               "reg_alpha": [0, 0.001, 0.005, 0.01, 0.05, 0.1],
               "reg_lambda": [0.05, 0.1, 0.5, 1.0]
               }
def param2(X_train, X_test, y_train, y_test, model, param_grid2):
    grid_obj,accuracy,auc_roc1, best_params=myXGBoost(X_train, X_test, y_train, y_test, model, param_grid2,3,subsample=bestparam1_['subsample'],colsample_bytree=bestparam1_['colsample_bytree'],max_depth=bestparam1_['max_depth'],min_child_weight=bestparam1_['min_child_weight'])
    return grid_obj,accuracy,auc_roc1, best_params

xgbobj2,as2,auc2,bestparam2_=myXGBoost(X_train, X_test, y_train, y_test, xgb, param_grid2, KFold=3)
print(as2)
print(bestparam2_)
print(auc2)
# Out:
# C:\Users\Hardika\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Hardika\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\Users\Hardika\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# ...

# %% [markdown]
# # Handling imbalance in data with Under sampling, over sampling and SMOTE(Synthetic Minority Over-sampling Technique)

# %%
###Taking already tuned models LR ,RF, and XGBoost to work with Resampling techniques

# %%
m1 = RandomForestClassifier(bootstrap=False, class_weight=None, criterion='gini',
            max_depth=6, max_features='log2', max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=4, min_samples_split=2,
            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
            oob_score=False, random_state=9, verbose=0, warm_start=False)

m2 = LogisticRegression(random_state=9,penalty='l1')

m3 = XGBClassifier(learning_rate =0.01,n_estimators=1000,max_depth=3,min_child_weight=12,gamma=0.2,subsample=0.8,colsample_bytree=0.8,reg_alpha=0.01,objective= 'binary:logistic',nthread=4,scale_pos_weight=1,seed=9)
model=[m1,m2,m3]
# Write your solution here :
def ImbalProcess(X, y,model):
    dict1=dict()
    X_train,X_test,y_train,y_test= train_test_split(X,y,test_size=0.30,random_state=9)
    dataset=[[X_train, X_test, y_train, y_test]]
    DataSamplelst=[0,' on Data Received',' on RandomUnderSampler',' on RandomOverSampler',' on SMOTE']
   
    rus = RandomUnderSampler(random_state=9)
    X_sampleU, y_sampleU =  rus.fit_sample(X, y)
    X_sample2, X_sample2t, y_sample2, y_sample2t= train_test_split(X_sampleU, y_sampleU,test_size=0.30,random_state=9)
    dataset.append([X_sample2, X_sample2t, y_sample2, y_sample2t])
    
    
    ros = RandomOverSampler(random_state=9)
    X_sampleO, y_sampleO =  ros.fit_sample(X, y)
    X_sample3, X_sample3t, y_sample3, y_sample3t= train_test_split(X_sampleO, y_sampleO,test_size=0.30,random_state=9)
    dataset.append([X_sample3, X_sample3t, y_sample3, y_sample3t])
    
    
    smote = SMOTE(random_state=9, kind="borderline2")
    X_sampleS, y_sampleS =  ros.fit_sample(X, y)
    X_sample4, X_sample4t, y_sample4, y_sample4t= train_test_split(X_sampleS, y_sampleS,test_size=0.30,random_state=9)
    dataset.append([X_sample4, X_sample4t, y_sample4, y_sample4t])
    
    roc_old=0
    roc_new=0
    for m in model:
        i=1
        for X_train, X_test, y_train, y_test in dataset:
            m.fit(X_train, y_train)
            y_pred=m.predict(X_test)
            roc_new=roc_auc_score(y_test, y_pred)
            as_new=accuracy_score(y_test, y_pred)
            dict1[str(m)[:str(m).index('(')]+str(DataSamplelst[i])]=[as_new,roc_new,classification_report(y_test, y_pred),list(confusion_matrix(y_test, y_pred))]
            i+=1
    return dict1
dict2=dict()
ImbalProcess(X,y,model)
# Out:
# {'LogisticRegression on Data Received': [0.8116666666666666,
#   0.6105703631056595,
#   '             precision    recall  f1-score   support\n\n          0       0.82      0.97      0.89      7023\n          1       0.70      0.25      0.37      1977\n\navg / total       0.79      0.81      0.78      9000\n',
#   [array([6807,  216], dtype=int64), array([1479,  498], dtype=int64)]],
#  'LogisticRegression on RandomOverSampler': [0.6776517583279834,
#   0.6781096714936193,
#   '             precision    recall  f1-score   support\n\n          0       0.66      0.71      0.69      6915\n          1       0.70      0.64      0.67      7104\n\navg / total       0.68      0.68      0.68     14019\n',
#   [array([4924, 1991], dtype=int64), array([2528, 4576], dtype=int64)]],
#  'LogisticRegression on RandomUnderSampler': [0.683073832245103,
#   0.6836609721128409,
# ...

# %% [raw]
# /*****
# Best result I can see is with parameter tuned XGBoost on test data
# Accuracy=0.8185555555555556
# AUC=0.6529626155724623
#         precision    recall  f1-score   support
#         0.84      0.95      0.89      7023
#         0.66      0.36      0.46      1977
# total   0.80      0.82      0.80      9000
#
# Confusion matrix [[6660,  363]
#                  [1270,  707]]
#
# Even results for Logistic regression and RandomForest with parameter tuning are close.
# I also noticed Feature selection not helped with less no. of features.
# Even Under Sampling ,Oversampling or SMOTE not helped in this case.
#
# ******/
